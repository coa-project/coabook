# %% [markdown]
# # Help on coa.error (pycoa release 1.0)
#
# ## Making PyCoA available
# If executed locally

# %%
import sys
sys.path.insert(1, '../pycoa')

# %% [markdown]
# If executed on a server (e.g. Google Colab ), you should install cocoa via pip3

# %%
# !pip3 install -q git+https://github.com/coa-project/pycoa.git

# %%
import coa.error as ce

# %%
help(ce)
# Out:
# Help on module coa.error in coa:
#
# NAME
#     coa.error
#
# DESCRIPTION
#     Project : PyCoA
#     Date :    april-november 2020
#     Authors : Olivier Dadoun, Julien Browaeys, Tristan Beau
#     Copyright ©pycoa.fr
#     License: See joint LICENSE file
#
#     Module : coa.error
#     About :
#
#     Main class definitions for error management within the pycoa framework.
#     All Coa exceptions should derive from the main CoaError class.
#
# CLASSES
#     builtins.Exception(builtins.BaseException)
#         CoaError
#             CoaConnectionError(CoaError, builtins.ConnectionError)
#             CoaDbError
#             CoaKeyError(CoaError, builtins.KeyError)
#             CoaLookupError(CoaError, builtins.LookupError)
#             CoaNotManagedError
#             CoaTypeError(CoaError, builtins.TypeError)
#             CoaWhereError(CoaError, builtins.IndexError)
#
#     class CoaConnectionError(CoaError, builtins.ConnectionError)
#      |  CoaConnectionError(message)
# ...
